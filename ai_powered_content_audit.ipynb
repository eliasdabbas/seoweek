# %% [markdown]
# # AI-Powered Content Audit - Using Google's Helpful Content Guidelines

# %%
import json
import os
import advertools as adv
import pandas as pd
pd.options.display.max_columns = None
import openai
client = openai.OpenAI(api_key=os.environ['OPENAI_API_KEY'])


questions_df = pd.read_csv("data/quality_guidelines.csv")
questions = questions_df['question'].tolist()[:20]
questions[:5]
# Out:
# ['Does the content provide original information, reporting, research, or analysis?',
#  'Does the content provide a substantial, complete, or comprehensive description of the topic?',
#  'Does the content provide insightful analysis or interesting information that is beyond the obvious?',
#  'If the content draws on other sources, does it avoid simply copying or rewriting those sources, and instead provide substantial additional value and originality?',
#  'Does the main heading or page title provide a descriptive, helpful summary of the content?']

# %% [markdown]
# ## Crawl a website

# %%
# adv.crawl("https://seoweek.org/", "data/seoweek.jsonl", follow_links=True)

# %% [markdown]
# ## Read the crawled file into a DataFrame

# %%
seoweek = pd.read_json('data/seoweek.jsonl', lines=True)

# %% [markdown]
# ## Filter the desired pages

# %%
podcasts = seoweek[seoweek['body_text'].str.contains('transcript', case=False)][['url','title', 'body_text']]

# %%
podcasts.head()
# Out:
#                                     url  \
# 1   https://seoweek.org/devin-bramhall/
# 2   https://seoweek.org/crystal-carter/
# 3       https://seoweek.org/jeff-coyle/
# 6  https://seoweek.org/bianca-anderson/
# 7     https://seoweek.org/wil-reynolds/
#
#                                                title  \
# 1      Stop Doing Marketing Featuring Devin Bramhall
# 2  Diving into Deepseek Generative Search Optimiz...
# 3  Authoritative Intelligence: Evolving IR, NLP, ...
# 6  F$%@ Traffic: Prioritizing Conversions Over Va...
# 7  The "Other" AI That is Hurting Your Organic Tr...
#
#                                            body_text
# 1  \n\t\t \n \n X \n \n\t\t HOME \n AGENDA \n \t\...
# 2  \n\t\t \n \n X \n \n\t\t HOME \n AGENDA \n \t\...
# 3  \n\t\t \n \n X \n \n\t\t HOME \n AGENDA \n \t\...
# 6  \n\t\t \n \n X \n \n\t\t HOME \n AGENDA \n \t\...
# 7  \n\t\t \n \n X \n \n\t\t HOME \n AGENDA \n \t\...

# %%
prompt_intro = """Please answer the following questions about this article.
Respond in JSON where questions are keys and answers are values.
Send the JSON string only.
Answers should be boolean only."""

# %% [markdown]
# ## Loop through the pages, and make a request to evaluate the article with all questions

# %%
responses = []

for url, title, body in podcasts.values:
    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "user",
            "content": f"""
            {prompt_intro}

            Questions: {questions}

            -------------
            Article Title: {title}

            -------------
            Article Text: {body}

"""}
        ],
        temperature=0,
        response_format={"type": "json_object"},
    )
    responses.append((url, title, response))

# %% [markdown]
# # Merge all responses in one DataFrame

# %%
dflist = []
for url, title, evaluation in responses:
    d = json.loads(evaluation.choices[0].message.content)
    df = pd.DataFrame({
        'question': d.keys(),
        'answer': d.values()
    })
    df['url'] = url
    df['title'] = title
    dflist.append(df)
final_df = pd.concat(dflist)[['url', 'title', 'question', 'answer']]
final_df.to_csv("data/evaluations.csv", index=False)

# %%
evaluations_df = pd.read_csv("data/evaluations.csv")

# %%
evaluations_df.sample(15)
# Out:
#                                       url  \
# 191    https://seoweek.org/tom-critchlow/
# 210     https://seoweek.org/ross-hudgens/
# 159       https://seoweek.org/cindy-krum/
# 3     https://seoweek.org/devin-bramhall/
# 300     https://seoweek.org/elias-dabbas/
# 252     https://seoweek.org/dan-petrovic/
# 155       https://seoweek.org/cindy-krum/
# 9     https://seoweek.org/devin-bramhall/
# 204     https://seoweek.org/ross-hudgens/
# 103        https://seoweek.org/jori-ford/
# 78   https://seoweek.org/bianca-anderson/
# 189    https://seoweek.org/tom-critchlow/
# 294       https://seoweek.org/talia-wolf/
# 233    https://seoweek.org/ross-simmonds/
# 184    https://seoweek.org/tom-critchlow/
#
#                                                  title  \
# 191  Executive Presence: How To Get Buy In and Budg...
# 210  The Evolving Content Marketing Playbook Featur...
# 159              Word to Your MUM Featuring Cindy Krum
# 3        Stop Doing Marketing Featuring Devin Bramhall
# 300  The Rise of the SEO Data Scientist Featuring E...
# 252  Beyond Rank Tracking: Analyzing Brand Percepti...
# 155              Word to Your MUM Featuring Cindy Krum
# 9        Stop Doing Marketing Featuring Devin Bramhall
# 204  The Evolving Content Marketing Playbook Featur...
# 103  Hybrid Engine Optimization: A Crawler Driven A...
# 78   F$%@ Traffic: Prioritizing Conversions Over Va...
# 189  Executive Presence: How To Get Buy In and Budg...
# 294  Stop Chasing Conversions: Win More Customers w...
# 233  Search, AI & UGC: Navigating the Future of Goo...
# 184  Executive Presence: How To Get Buy In and Budg...
#
#                                               question  answer
# 191  Is the content carefully crafted with individu...    True
# 210  Is the content well-produced, appearing polish...    True
# 159  Will someone reading your content leave feelin...    True
# 3    If the content draws on other sources, does it...    True
# 300  Does the content provide original information,...    True
# 252  Does the content present information in a way ...    True
# 155  Is the content free of easily-verified factual...    True
# 9    Is the content free of spelling or stylistic i...    True
# 204  Does the main heading or page title provide a ...    True
# 103  If the content draws on other sources, does it...    True
# 78   After reading your content, will someone leave...    True
# 189  Is the content free of spelling or stylistic i...    True
# 294  Is this content written or reviewed by an expe...    True
# 233  If someone researched the site producing the c...    True
# 184  Does the main heading or page title provide a ...    True

# %%
evaluations_df.groupby('url')['answer'].mean().reset_index().style.background_gradient(subset=['answer'])
# Out:
# <style type="text/css">
# #T_ff2b4_row0_col1, #T_ff2b4_row2_col1, #T_ff2b4_row3_col1, #T_ff2b4_row4_col1, #T_ff2b4_row5_col1, #T_ff2b4_row6_col1, #T_ff2b4_row7_col1, #T_ff2b4_row8_col1, #T_ff2b4_row9_col1, #T_ff2b4_row10_col1, #T_ff2b4_row11_col1, #T_ff2b4_row12_col1, #T_ff2b4_row13_col1, #T_ff2b4_row14_col1, #T_ff2b4_row15_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ff2b4_row1_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_ff2b4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff2b4_level0_col0" class="col_heading level0 col0" >url</th>
#       <th id="T_ff2b4_level0_col1" class="col_heading level0 col1" >answer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff2b4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff2b4_row0_col0" class="data row0 col0" >https://seoweek.org/aleyda-solis/</td>
#       <td id="T_ff2b4_row0_col1" class="data row0 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff2b4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ff2b4_row1_col0" class="data row1 col0" >https://seoweek.org/bianca-anderson/</td>
#       <td id="T_ff2b4_row1_col1" class="data row1 col1" >0.950000</td>
#     </tr>
#     <tr>
#       <th id="T_ff2b4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ff2b4_row2_col0" class="data row2 col0" >https://seoweek.org/cindy-krum/</td>
#       <td id="T_ff2b4_row2_col1" class="data row2 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff2b4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ff2b4_row3_col0" class="data row3 col0" >https://seoweek.org/crystal-carter/</td>
#       <td id="T_ff2b4_row3_col1" class="data row3 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff2b4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ff2b4_row4_col0" class="data row4 col0" >https://seoweek.org/dan-petrovic/</td>
#       <td id="T_ff2b4_row4_col1" class="data row4 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff2b4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ff2b4_row5_col0" class="data row5 col0" >https://seoweek.org/devin-bramhall/</td>
#       <td id="T_ff2b4_row5_col1" class="data row5 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff2b4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ff2b4_row6_col0" class="data row6 col0" >https://seoweek.org/elias-dabbas/</td>
#       <td id="T_ff2b4_row6_col1" class="data row6 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff2b4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ff2b4_row7_col0" class="data row7 col0" >https://seoweek.org/jeff-coyle/</td>
#       <td id="T_ff2b4_row7_col1" class="data row7 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff2b4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ff2b4_row8_col0" class="data row8 col0" >https://seoweek.org/jori-ford/</td>
#       <td id="T_ff2b4_row8_col1" class="data row8 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff2b4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ff2b4_row9_col0" class="data row9 col0" >https://seoweek.org/nick-eubanks/</td>
#       <td id="T_ff2b4_row9_col1" class="data row9 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff2b4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ff2b4_row10_col0" class="data row10 col0" >https://seoweek.org/ross-hudgens/</td>
#       <td id="T_ff2b4_row10_col1" class="data row10 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff2b4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ff2b4_row11_col0" class="data row11 col0" >https://seoweek.org/ross-simmonds/</td>
#       <td id="T_ff2b4_row11_col1" class="data row11 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff2b4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ff2b4_row12_col0" class="data row12 col0" >https://seoweek.org/talia-wolf/</td>
#       <td id="T_ff2b4_row12_col1" class="data row12 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff2b4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ff2b4_row13_col0" class="data row13 col0" >https://seoweek.org/tom-critchlow/</td>
#       <td id="T_ff2b4_row13_col1" class="data row13 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff2b4_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ff2b4_row14_col0" class="data row14 col0" >https://seoweek.org/wil-reynolds/</td>
#       <td id="T_ff2b4_row14_col1" class="data row14 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff2b4_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ff2b4_row15_col0" class="data row15 col0" >https://seoweek.org/will-critchlow/</td>
#       <td id="T_ff2b4_row15_col1" class="data row15 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
evaluations_df.groupby('question')['answer'].mean().reset_index().style.background_gradient(subset=['answer'])
# Out:
# <style type="text/css">
# #T_476b0_row0_col1, #T_476b0_row1_col1, #T_476b0_row2_col1, #T_476b0_row3_col1, #T_476b0_row4_col1, #T_476b0_row5_col1, #T_476b0_row6_col1, #T_476b0_row8_col1, #T_476b0_row9_col1, #T_476b0_row10_col1, #T_476b0_row11_col1, #T_476b0_row12_col1, #T_476b0_row13_col1, #T_476b0_row14_col1, #T_476b0_row15_col1, #T_476b0_row16_col1, #T_476b0_row17_col1, #T_476b0_row18_col1, #T_476b0_row19_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_476b0_row7_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_476b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_476b0_level0_col0" class="col_heading level0 col0" >question</th>
#       <th id="T_476b0_level0_col1" class="col_heading level0 col1" >answer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_476b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_476b0_row0_col0" class="data row0 col0" >After reading your content, will someone leave feeling they've learned enough about a topic to help achieve their goal?</td>
#       <td id="T_476b0_row0_col1" class="data row0 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_476b0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_476b0_row1_col0" class="data row1 col0" >Do you have an existing or intended audience for your business or site that would find the content useful if they came directly to you?</td>
#       <td id="T_476b0_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_476b0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_476b0_row2_col0" class="data row2 col0" >Does the content present information in a way that makes you want to trust it, such as clear sourcing, evidence of the expertise involved, background about the author or the site that publishes it, such as through links to an author page or a site's About page?</td>
#       <td id="T_476b0_row2_col1" class="data row2 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_476b0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_476b0_row3_col0" class="data row3 col0" >Does the content provide a substantial, complete, or comprehensive description of the topic?</td>
#       <td id="T_476b0_row3_col1" class="data row3 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_476b0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_476b0_row4_col0" class="data row4 col0" >Does the content provide insightful analysis or interesting information that is beyond the obvious?</td>
#       <td id="T_476b0_row4_col1" class="data row4 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_476b0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_476b0_row5_col0" class="data row5 col0" >Does the content provide original information, reporting, research, or analysis?</td>
#       <td id="T_476b0_row5_col1" class="data row5 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_476b0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_476b0_row6_col0" class="data row6 col0" >Does the content provide substantial value when compared to other pages in search results?</td>
#       <td id="T_476b0_row6_col1" class="data row6 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_476b0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_476b0_row7_col0" class="data row7 col0" >Does the main heading or page title avoid exaggerating or being shocking in nature?</td>
#       <td id="T_476b0_row7_col1" class="data row7 col1" >0.937500</td>
#     </tr>
#     <tr>
#       <th id="T_476b0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_476b0_row8_col0" class="data row8 col0" >Does the main heading or page title provide a descriptive, helpful summary of the content?</td>
#       <td id="T_476b0_row8_col1" class="data row8 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_476b0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_476b0_row9_col0" class="data row9 col0" >Does your content clearly demonstrate first-hand expertise and a depth of knowledge (for example, expertise that comes from having actually used a product or service, or visiting a place)?</td>
#       <td id="T_476b0_row9_col1" class="data row9 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_476b0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_476b0_row10_col0" class="data row10 col0" >If someone researched the site producing the content, would they come away with an impression that it is well-trusted or widely-recognized as an authority on its topic?</td>
#       <td id="T_476b0_row10_col1" class="data row10 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_476b0_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_476b0_row11_col0" class="data row11 col0" >If the content draws on other sources, does it avoid simply copying or rewriting those sources, and instead provide substantial additional value and originality?</td>
#       <td id="T_476b0_row11_col1" class="data row11 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_476b0_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_476b0_row12_col0" class="data row12 col0" >Is the content carefully crafted with individual pages or sites receiving proper attention and care, rather than being mass-produced or widely outsourced?</td>
#       <td id="T_476b0_row12_col1" class="data row12 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_476b0_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_476b0_row13_col0" class="data row13 col0" >Is the content free of easily-verified factual errors?</td>
#       <td id="T_476b0_row13_col1" class="data row13 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_476b0_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_476b0_row14_col0" class="data row14 col0" >Is the content free of spelling or stylistic issues?</td>
#       <td id="T_476b0_row14_col1" class="data row14 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_476b0_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_476b0_row15_col0" class="data row15 col0" >Is the content well-produced, appearing polished and thoughtfully created?</td>
#       <td id="T_476b0_row15_col1" class="data row15 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_476b0_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_476b0_row16_col0" class="data row16 col0" >Is this content written or reviewed by an expert or enthusiast who demonstrably knows the topic well?</td>
#       <td id="T_476b0_row16_col1" class="data row16 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_476b0_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_476b0_row17_col0" class="data row17 col0" >Is this the sort of page you'd want to bookmark, share with a friend, or recommend?</td>
#       <td id="T_476b0_row17_col1" class="data row17 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_476b0_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_476b0_row18_col0" class="data row18 col0" >Will someone reading your content leave feeling like they've had a satisfying experience?</td>
#       <td id="T_476b0_row18_col1" class="data row18 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_476b0_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_476b0_row19_col0" class="data row19 col0" >Would you expect to see this content in or referenced by a printed magazine, encyclopedia, or book?</td>
#       <td id="T_476b0_row19_col1" class="data row19 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
